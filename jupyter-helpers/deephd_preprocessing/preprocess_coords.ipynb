# %%
from IPython import get_ipython
ipython = get_ipython()
ipython.magic('load_ext autoreload')
ipython.magic('autoreload 2')

import os
import glob
import numpy as np
import pandas as pd
import prody
import matplotlib.pyplot as plt
import scipy.spatial.distance as sdst
from itertools import combinations

from Bio.PDB import PDBIO
from Bio.PDB import PDBParser
from Bio.PDB.Polypeptide import PPBuilder
from Bio import BiopythonWarning
import warnings
with warnings.catch_warnings():
    warnings.simplefilter('ignore', BiopythonWarning)

fro

# %%
paths_pdb = sorted(glob.glob('/mnt/data1T/data/annaha/homod/pdb_raw/*_raw.pdb'))

# %%
for x in paths_pdb:
    q = read_homo_pdb_coords_cacb(x, return_models=True)
    print('{} -> {}'.format( q['pdb'], len(q['models']) ))
# Out:
# 10gs_raw.pdb -> 2
# 117e_raw.pdb -> 2
# 11as_raw.pdb -> 2
# 11ba_raw.pdb -> 2
# 11bg_raw.pdb -> 2
# 11gs_raw.pdb -> 2
# 121p_raw.pdb -> 2
# 12as_raw.pdb -> 2
# 12gs_raw.pdb -> 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-ad4e9abbb4b4> in <module>
#       1 for x in paths_pdb:
# ----> 2     q = read_homo_pdb_coords_cacb(x, return_models=True)
#       3     print('{} -> {}'.format( q['pdb'], len(q['models']) ))
#
# <ipython-input-71-60f292e8000b> in read_homo_pdb_coords_cacb(path_pdb, calc_dst, return_models, pdb_parser)
#      30         models_coords_cb.append(coords_cb_)
#      31         models_res.append(res_)
# ---> 32     models_coords_ca = np.stack(models_coords_ca).astype(np.float32)
#      33     models_coords_cb = np.stack(models_coords_cb).astype(np.float32)
#      34     models_res = np.stack(models_res)
#
# ...

# %%
q['models'][0]
# Out:
# <Chain id=A>

# %%
dst_0 = np.abs(q['coords_ca'][0] - q['coords_cb'][0]).mean(axis=-1) / np.abs(q['coords_ca'][0]).mean(axis=-1)
dst_1 = np.abs(q['coords_ca'][1] - q['coords_cb'][1]).mean(axis=-1) / np.abs(q['coords_ca'][1]).mean(axis=-1)

# %%
plt.plot(dst_0)
plt.plot(dst_1)

# %%
len(dst_1)
# Out:
# 208
